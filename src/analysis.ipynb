# %%
import pandas as pd

# %% [markdown]
# ### Temperature vs Public Transport

# %%
survey = pd.read_csv('../survey_processed.csv')
survey.sort_values(by='avg_PT_satisfaction', ascending=False, inplace=True)
survey
# Out:
#              D3_Cityrecode  avg_PT_satisfaction  avg_Life_satisfaction  \
# 55                  Zürich             3.677457               3.699309
# 0                     Wien             3.445867               3.410256
# 22                 Rostock             3.268029               3.514052
# 36               Rotterdam             3.263990               3.310345
# 6                    Praha             3.241706               3.217391
# 32              Luxembourg             3.208134               3.542790
# 8   Helsinki / Helsingfors             3.187648               3.355217
# 53                    Oslo             3.178984               3.647936
# 14              Strasbourg             3.126492               3.294529
# 19                 Hamburg             3.111244               3.526627
# 54                  Genève             3.096890               3.471742
# 21                 München             3.083628               3.475467
# ...

# %%
df = pd.read_csv('../cars_per_ppl_sample.csv')
# df[['Country_sample', 'D3_Cityrecode']].to_csv(
    # '../cars_per_ppl_sample_countries.csv',
    # index=False,
# )
df[['Country_sample', 'D3_Cityrecode']].to_csv(
    '../avg_salary.csv',
    index=False
)

# %%
df
# Out:
#     Country_sample           D3_Cityrecode   cars_per_thousand_ppl
# 0          Austria                    Wien                     574
# 1          Belgium     Bruxelles / Brussel                     506
# 2          Belgium               Antwerpen                     506
# 3          Belgium                   Liège                     506
# 4      Switzerland                  Zürich                     546
# 5      Switzerland                  Genève                     546
# 6           Cyprus                Lefkosia                     475
# 7   Czech Republic                   Praha                     611
# 8          Germany                  Berlin                     586
# 9          Germany                 Hamburg                     586
# 10         Germany                 München                     586
# 11         Germany                   Essen                     586
# 12         Germany                 Leipzig                     586
# ...

# %%
df = pd.read_csv('../temperature_sample.csv')

# %%
df['avg_jan_temp_c'] = ((df[' avg_jan_temp_f'] - 32) * 5/9).round(2)
df = df.drop(' avg_jan_temp_f', axis=1)
df
# Out:
#     Country_sample           D3_Cityrecode  avg_jan_temp_c
# 0          Austria                    Wien            3.74
# 1          Belgium     Bruxelles / Brussel            5.43
# 2          Belgium               Antwerpen            5.57
# 3          Belgium                   Liège            4.18
# 4      Switzerland                  Zürich            3.22
# 5      Switzerland                  Genève            4.08
# 6           Cyprus                Lefkosia           23.36
# 7   Czech Republic                   Praha            2.73
# 8          Germany                  Berlin            4.99
# 9          Germany                 Hamburg            4.99
# 10         Germany                 München            4.39
# 11         Germany                   Essen            4.99
# 12         Germany                 Leipzig            4.99
# 13         Germany                Dortmund            4.99
# 14         Germany                 Rostock            4.99
# ...
